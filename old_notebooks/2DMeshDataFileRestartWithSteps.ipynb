# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import random as random
from matplotlib import rcParams

                        
# create empty array to store float values
x = []
y = []
   

filelist=[]

for i in range(1,201):
    if i >= 0 and i <= 9:
        filelist.append("C:/Users/abc/C5_mesh_1_data.cbf/C5_mesh_1_data.cbf00000%s.dat" %i)
        
    if i >= 10 and i <= 99:
        filelist.append("C:/Users/abc/C5_mesh_1_data.cbf/C5_mesh_1_data.cbf0000%s.dat" %i)
        
    if i >= 100 and i <= 200:
        filelist.append("C:/Users/abc/C5_mesh_1_data.cbf/C5_mesh_1_data.cbf000%s.dat" %i)

for fname in filelist:
    data=np.loadtxt(fname, dtype = np.float64) #, encoding='cp850', 'r')
#     if rows.startswith("#"):
#         continue
   # np_array = np.array(rows.strip().split(), dtype = np.float64)
    x = data[:,0]
    y = data[:,1]
#     x.append(data[0])
#     y.append(data[1])
    plt.plot(x, y)#, label = fname)

# # go through all dat files in folder
# dirName = "C:/Users/abc/C5_mesh_1_data_shortened.cbf"
# with os.scandir(dirName) as mesh01_data:
#         for file in fileList:
#             dirFile = dirName + "/" + file.name
#             print(dirFile)
#             with open (dirFile, 'r', encoding='cp850') as mesh_data:
#                 for rows in mesh_data:
#                 # ignore lines that start with #
#                     if rows.startswith("#"):
#                         continue
#                     np_array = np.array(rows.strip().split(), dtype = np.float64)
#                     x.append(np_array[0])
#                     y.append(np_array[1])
                    
#                     if np_array[2] == "nan":
#                         break
                    
                       
    


# create plot with x and y labels along with plot title
plt.plot(figsize=(400,200))
#plt.plot(x, y, label = 'Mesh Data File 200!')
plt.xlabel('q_A^-1')
plt.ylabel('I')
plt.title('Mesh Data Files')

# second value in parentheses is how many tick marks you want on the graph
# plt.xlim(0,4.5)
# plt.ylim(0,2.5)
plt.autoscale()
plt.legend()
rcParams['figure.figsize'] = 80,40
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x
# Out:
# array([1.105228e-03, 3.315685e-03, 5.526141e-03, ..., 4.415387e+00,
#        4.417597e+00, 4.419807e+00])

# %%
y
# Out:
# array([ 0.8420088,  0.9459304,  1.327505 , ..., -0.4235375, -1.99708  ,
#         0.1431295])
